# %%
import requests
import pandas as pd
import json
import time

# %%
def parse_vacancies(city_id, vacancy):
    try:
        # Specify the URL for the vacancies API with city and vacancy parameters
        url = 'https://api.hh.ru/vacancies'
        params = {
            'text': vacancy,
            'area': city_id,
            'per_page': 100,
            'search_field': 'name'
        }

        # Send a GET request to the API endpoint
        response = requests.get(url, params=params)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the JSON response
            vacancies_data = response.json()

            # Extract and process the relevant information
            for vacancy_info in vacancies_data['items']:
                vacancy_id = vacancy_info['id']
                vacancy_name = vacancy_info['name']
                salary_info = vacancy_info['salary']
                key_skills = vacancy_info.get('key_skills', [])
                key_skills_1 = [skill['name'] for skill in key_skills]
                description = vacancy_info['snippet']['requirement']
                vacancy_salary = vacancy_info.get('salary', {})

                print(f"Vacancy ID: {vacancy_id}")
                print(f"Title: {vacancy_name}")
                print(f"Description: {description}")

                if vacancy_salary:
                    salary_from = vacancy_salary.get('from', 'N/A')
                    salary_to = vacancy_salary.get('to', 'N/A')
                    currency = vacancy_salary.get('currency', 'N/A')
                    print(f"Salary: {salary_from} - {salary_to} {currency}")

                #print("=" * 30)
        else:
            print(f"Failed to retrieve data. Status code: {response.status_code}")
            print(f"Response content: {response.text}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
city_id = 1  # Moscow city ID (you may need to look up the correct city ID)
vacancy = 'python developer'  # You can replace this with the desired vacancy

# Call the function to parse vacancies
parse_vacancies(city_id, vacancy)
# Out:
# Vacancy ID: 90415076
# Title: Стажер/разработчик Python
# Description: Знания Linux. Будет плюсом задание Go/C/C++, знание сетей.
# Vacancy ID: 91095852
# Title: Python разработчик (FastAPI)
# Description: Знания/опыт внедрения или поддержки чистой архитектуры. Опыт работы с профильными технологиями: <highlighttext>Python</highlighttext> 3.11+, FastAPI, SQLAlchemy, Redis, Pytest.
# Vacancy ID: 91095951
# Title: Backend разработчик (Python FastAPI)
# Description: Знания и опыт в профильных технологиях: <highlighttext>Python</highlighttext>, FastAPI, SQLalchemy, Pytest. Kafka (теоретические знания о технологии). Готовность ездить в офис.
# Vacancy ID: 90551583
# Title: Бэкенд-разработчик Python Django
# Description: опыт работы от 1 года.
# Vacancy ID: 91075564
# Title: Backend Developer (Python, IAM)
# Description: Минимум 2 года опыта <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext>. Способность самостоятельно уточнять требования по задачам, декомпозировать, реализовывать, тестировать и закатывать до прода.
# Vacancy ID: 90204534
# Title: Python-разработчик / Junior Python Developer
# Description: Требуемый опыт работы: опыт в программировании на <highlighttext>Python</highlighttext>. Ключевые навыки: <highlighttext>Python</highlighttext>, Linux, MySQL, Apache HTTP Server, SQL, Flask.
# Salary: 100000 - 150000 RUR
# Vacancy ID: 91076606
# Title: Python разработчик
# Description: Опыт программирования на <highlighttext>Python</highlighttext> 3.8+. Примеры успешных разработанных решений в продакшн. Знание шаблонов проектирования и принципов <highlighttext>разработки</highlighttext>, умение...
# Vacancy ID: 90865664
# Title: Стажер-разработчик Python (финтех)
# Description: Уверенное знание <highlighttext>Python</highlighttext>. Опыт работы с фреймворком Django. Опыт работы с СУБД PostgreSQL. Знание ООП и структур данных.
# Vacancy ID: 91105550
# Title: Python разработчик
# Description: Уверенные навыки программирования на <highlighttext>Python</highlighttext> на уровне не ниже middle. Опыт коммерческой <highlighttext>разработки</highlighttext>. Ответственность, самостоятельность, умение работать в команде.
# Vacancy ID: 90092857
# Title: Бэкенд-разработчик Python
# Description: 1) 1+ год опыта работы в качестве бэкенд-<highlighttext>разработчика</highlighttext> (<highlighttext>Python</highlighttext>). 2) Опыт в <highlighttext>разработке</highlighttext> чат-ботов на aiogram(несколько...
# Salary: 60000 - 110000 RUR
# Vacancy ID: 88676763
# Title: Backend разработчик (Python)
# Description: Опыт асинхронного программирования, работы с микросервисной архитектурой. Опыт <highlighttext>разработки</highlighttext> многопоточных приложений. Опыт <highlighttext>разработки</highlighttext> распределенных приложений. Понимание работы с Docker и...
# Vacancy ID: 90657302
# Title: Python-разработчик (Управление данными)
# Description: <highlighttext>Python</highlighttext>, Django, Flask, SQL. Знание Kubernetes, Kubflow, Docker, ML будет преимуществом.
# Vacancy ID: 90947229
# Title: Разработчик Python
# Description: Знание фреймворка FastAPI. Базовые знания HTML, CSS, JavaScript. Умение работать с Git. Знание SQL, опыт работы с PostgreSQL, умение использовать...
# Salary: 100000 - None RUR
# Vacancy ID: 90956899
# Title: Backend-разработчик Python Django
# Description: Коммерческий опыт <highlighttext>разработки</highlighttext> серверной части приложений на Django <highlighttext>Python</highlighttext> от 3 лет. Опыт программирования на JavaScript (ES5/ES6).
# Salary: None - 80000 RUR
# Vacancy ID: 91037679
# Title: Python-разработчик в Рег.облако
# Description: Глубокие знания <highlighttext>Python</highlighttext>. Умение работать с CУБД и ORM: MySQL, SQLAlchemy + Alembic. Умение писать чистый и поддерживаемый код.
# Vacancy ID: 90521379
# Title: Python Developer (junior)
# Description: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> от 0,6 мес., и выше. Опыт работы с FastAPI. Покрытие тестами. Знание базовых паттернов.
# Salary: 80000 - 100000 RUR
# Vacancy ID: 91000602
# Title: Middle Python Developer (Удаленно)
# Description: Опыт <highlighttext>разработки</highlighttext> бэкенда на <highlighttext>Python</highlighttext> 2-3 года. Уверенное владение <highlighttext>Python</highlighttext>3+. Умение писать SQL запросы. Опыт работы с...
# Vacancy ID: 90578989
# Title: Backend Python Django Developer
# Description: Опыт работы с <highlighttext>Python</highlighttext>. Уверенное знание <highlighttext>Python</highlighttext> и в частности Django. Знание SQL (MySQL). Опыт работы с Git, Docker, GitFlow.
# Salary: 40000 - 90000 RUR
# Vacancy ID: 90883559
# Title: Разработчик Python (Junior+/Middle)
# Description: Знание структур и типов данных в <highlighttext>Python</highlighttext>. Знание как управлять зависимостями в приложениях на <highlighttext>python</highlighttext> (pip/poetry/pipenv).
# Vacancy ID: 90267843
# Title: Программист/Разработчик Python/Django Junior
# Description: Опыт веб-<highlighttext>разработки</highlighttext> от 6 месяцев, умение разбираться в чужом коде. Опыт <highlighttext>разработки</highlighttext> сложных проектов. Обязателен опыт работы с django...
# Salary: 70000 - 100000 RUR
# Vacancy ID: 90877456
# Title: Go/Rust & Python разработчик
# Description: Знакомство с системами Linux - приветствуется. Опыт работы в <highlighttext>разработке</highlighttext> серверных приложений с использованием указанных языков. Обязательное знание русского языка.
# Salary: 100000 - 180000 RUR
# Vacancy ID: 90224812
# Title: Python Backend Developer
# Description: None
# Salary: 120000 - None RUR
# Vacancy ID: 89545514
# Title: Python-разработчик
# Description: Знание <highlighttext>Python</highlighttext> и коммерческий опыт работы от 1 года. Опыт работы с GNU/Linux. Опыт <highlighttext>разработки</highlighttext> прикладного ПО.
# Vacancy ID: 90987202
# Title: Веб-разработчик Python/JS (Django, Vue.js)
# Description: Обязательные навыки в коммерческой <highlighttext>разработки</highlighttext> на Django с ORM от 2 лет. Обязательны навыки <highlighttext>разработки</highlighttext> на JavaScript и фреймворки VueJS...
# Salary: 90000 - 140000 RUR
# Vacancy ID: 89204520
# Title: Python-разработчик (уровень middle)
# Description: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> 3+ от 2 лет. Хорошее знание Django и FastAPI (можно что-то одно на менее...
# Vacancy ID: 90077186
# Title: Инженер-разработчик Python
# Description: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>python</highlighttext> от 3х лет. Опыт работы с FastAPI, Flask или Django DRF. Понимание основ работы баз...
# Vacancy ID: 90854852
# Title: Python-разработчик
# Description: Работал c FastAPI. Имеешь опыт написания тестов. Имеешь опыт code review. Используешь линтеры. Работал с kafka/rabbitmq.
# Vacancy ID: 90865663
# Title: Middle/Middle+ финтех разработчик на Python
# Description: Опыт работы в финтех проектах обязателен, опыт работы в платежных системах будет плюсом. Уверенное знание <highlighttext>Python</highlighttext>; Опыт работы с фреймворком...
# Salary: 80000 - None RUR
# Vacancy ID: 90982757
# Title: Python developer / FastAPI
# Description: Опыт написания интеграционных тестов. Владение асинхронным <highlighttext>Python</highlighttext> и современным фреймворком веб-<highlighttext>разработки</highlighttext> на его основе (fastapi, aiohttp) от 2-х...
# Vacancy ID: 90990068
# Title: Backend разработчик (Python/Go)
# Description: Уверенное знание Django (<highlighttext>Python</highlighttext>). Опыт с Django REST Framework. Уверенное знание SQL и опыт работы с различными БД.
# Vacancy ID: 90550206
# Title: Junior/Middle Python разработчик (in-house)
# Description: Опыт <highlighttext>разработки</highlighttext> веб-приложений не менее 2 лет. Знание <highlighttext>Python</highlighttext> и Django на уровне Junior/Middle. Опыт работы с Vue...
# Vacancy ID: 89498599
# Title: Python developer (remote)
# Description: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>python</highlighttext> 3 от 1.5-го года. Практический опыт <highlighttext>разработки</highlighttext> в команде от 1-го года с...
# Vacancy ID: 90869351
# Title: Python developer
# Description: Коммерческий опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> на фреймворках Aiohttp/ Aioamqp – от 3 лет. Понимание базовых принципов работы API. Отличное понимание ООП.
# Vacancy ID: 89447092
# Title: Backend разработчик (Python)
# Description: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext>. Опыт web-<highlighttext>разработки</highlighttext> с применением Django и/или Tornado. Опыт <highlighttext>разработки</highlighttext> RESTful HTTP API на Django...
# Salary: 60000 - None RUR
# Vacancy ID: 90367911
# Title: Python разработчик (middle)
# Description: Опыт коммерческой <highlighttext>разработки</highlighttext> веб-сервисов на Django от 3 лет. Экспертизу в работе с RabbitMQ, Docker/Docker Compose.
# Salary: 180000 - 250000 RUR
# Vacancy ID: 90918774
# Title: Back-end разработчик Web-приложений (Python)
# Description: Коммуникабельность, желание работать в команде и ориентированность на результат. Опыт <highlighttext>разработки</highlighttext> серверных приложений на языке <highlighttext>Python</highlighttext>. Опыт работы с ORM...
# Vacancy ID: 90275811
# Title: Разработчик Python / Computer Vision
# Description: Хорошие знания <highlighttext>Python</highlighttext> и умение писать на нем качественный и понятный код. Знание классического ML, классификация, кластеризация, регрессия.
# Salary: None - 250000 RUR
# Vacancy ID: 90607267
# Title: Программист Python
# Description: Опыт работы с версией языка <highlighttext>Python</highlighttext> 3. Понимание REST, json. Опыт работы с Fastapi, но можешь предложить и свои фреймворки...
# Vacancy ID: 90167043
# Title: Python developer (middle/senior)
# Description: Коммерческий опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> (Django) – от 3 лет. Знания SQL (MySQL, в будущем планируется переход на PostgreSQL).
# Vacancy ID: 90794228
# Title: Backend-разработчик (Python)
# Description: Опыт работы на коммерческом проекте с <highlighttext>Python</highlighttext>3. Опыт работы на коммерческом проекте FastAPI. Знание SQL, способов оптимизации запросов к...
# Salary: None - 110000 RUR
# Vacancy ID: 90616288
# Title: Программист Linux/Python
# Description: Уверенное знание и опыт <highlighttext>разработки</highlighttext>: *<highlighttext>Python</highlighttext>/Django. *Баз данных MariaDB (MySQL), SQLite. Знакомство с принципами построения архитектуры продукта. Опыт <highlighttext>разработки</highlighttext>...
# Salary: 250000 - None RUR
# Vacancy ID: 90657394
# Title: Программист-разработчик Python
# Description: Опыт <highlighttext>разработки</highlighttext> и высокий уровень знания <highlighttext>Python</highlighttext>, знание ООП. Опыт работы с Django. Опыт <highlighttext>разработки</highlighttext> задач асинхронного программирования.
# Vacancy ID: 88656282
# Title: Python разработчик/Python Developer (Продукт: ПАК)
# Description: Хорошее знание языка <highlighttext>Python</highlighttext>, опыт промышленной <highlighttext>разработки</highlighttext> от 2-х лет. Создание микросервисов. Опыт работы с инфраструктурой микросервисов (Docker/Kubernetes...
# Vacancy ID: 90237644
# Title: Программист Python
# Description: None
# Salary: 200000 - 400000 RUR
# Vacancy ID: 89854681
# Title: Backend-разработчик (Python)
# Description: Отличное знание и применение ООП. Опыт <highlighttext>разработки</highlighttext> от 1 года. Стек: <highlighttext>Python</highlighttext>, MongoDB, ClickHouse, FastAPI, PosgreSQL, Kafka, Docker, Go KrakenD.
# Salary: 100000 - None RUR
# Vacancy ID: 90791182
# Title: Backend-разработчик Django/Python
# Description: Умение быстро разбираться в чужом коде. Хорошие знания <highlighttext>Python</highlighttext> и Django/<highlighttext>Python</highlighttext>. Умение работать в команде, демонстрировать результаты своей работы.
# Salary: 140000 - 180000 RUR
# Vacancy ID: 91071820
# Title: Python Backend Developer
# Description: Обладаешь знаниями <highlighttext>Python</highlighttext> 3 и опытом промышленной <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> от 3х лет. У тебя есть знания многопоточного и...
# Vacancy ID: 90148326
# Title: Разработчик Python  (опыт от года)
# Description: Опыт работы с <highlighttext>Python</highlighttext> от года. Глубокие знания принципов ООП. Понимание работы реляционных баз данных. Навыки написания простых SQL запросов.
# Vacancy ID: 91040709
# Title: Python developer (Backend+ML)
# Description: Знание стандартных библиотек <highlighttext>Python</highlighttext>. Понимание ООП. Работа с git. Понимание мультипроцессинга, многопоточности. Умение писать асинхронный код. Будет преимуществом: Умение писать...
# Vacancy ID: 90293158
# Title: Python developer
# Description: Уверенное знание <highlighttext>python</highlighttext>3 (асинхронность и параллелизм). Уверенное знание принципов ООП. Опыт использования Django (или аналогов). Опыт проведения код-ревью.
# Vacancy ID: 90650229
# Title: Python разработчик
# Description: Отличное знание <highlighttext>Python</highlighttext> 3.6+. Знание Linux на уровне продвинутого пользователя, bash. Знание MongoDB, SQL, PostgreSQL. Опыт работы с...
# Vacancy ID: 90540695
# Title: Python-разработчик
# Description: От 5 лет коммерческого опыта на <highlighttext>Python</highlighttext>. Опыт работы с asyncio. Знакомство с веб-фреймворками <highlighttext>Python</highlighttext> (Django/FastAPI/Flask).
# Salary: None - 7000 USD
# Vacancy ID: 91095188
# Title: Программист Python
# Description: Опыт программирования <highlighttext>Python</highlighttext> от 3 лет. Опыт <highlighttext>разработки</highlighttext> и поддержки многопоточных и многопроцессных высоконагруженных систем уровня business critical (реализованных в...
# Vacancy ID: 90712821
# Title: Python developer (Удаленно)
# Description: Наличие опыта коммерческой <highlighttext>разработки</highlighttext> от 2 лет (минимум). - Наличие демонстрационного публичного пет проекта (желательно). - Обязательные навыки: <highlighttext>Python</highlighttext>, Django REST, Docker...
# Salary: None - 150000 RUR
# Vacancy ID: 90864239
# Title: Junior Fullstack разработчик (php/python/js)
# Description: Знание Bootstrap 5. JS на уровне написания собственных скриптов (AJAX, DOM). <highlighttext>Python</highlighttext> на уровне запросов к БД, работы с API...
# Salary: 60000 - 80000 RUR
# Vacancy ID: 90143268
# Title: Python разработчик
# Description: Опыт коммерческой <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> от 4х лет. Опыт <highlighttext>разработки</highlighttext> на FastAPI от 3х лет. Опыт построения RESTful...
# Vacancy ID: 89321400
# Title: Python разработчик
# Description: ...стандартными инструментами <highlighttext>разработчика</highlighttext> (Git, IDE, Ci/Cd, Docker, Bash). Будем плюсом: Опыт написания multithreading/multiprocessing программ на <highlighttext>Python</highlighttext>.
# Vacancy ID: 90986630
# Title: Python разработчик в команду THE CULTT
# Description: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> 3 от 3 лет. Опыт работы с фреймворками Django, FastAPI, Flask. Опыт работы с базами данных...
# Salary: None - 250000 RUR
# Vacancy ID: 86096984
# Title: Backend-тестировщик-программист (Python)
# Description: Опыт работы тестировщиком от 1 года. Работали со Swagger. Знание <highlighttext>Python</highlighttext> на уровне Junior для написание тестов. Опыт тестирования REST...
# Vacancy ID: 90352955
# Title: Python-разработчик
# Description: ты хороший командный игрок. - просто любишь, чтобы твой код работал эффективно. - при том стоимость - "ресурсы: память | время" были обоснованы.
# Salary: 120000 - 150000 RUR
# Vacancy ID: 91089210
# Title: Python разработчик
# Description: ...<highlighttext>разработки</highlighttext> на Java. Опыт <highlighttext>разработки</highlighttext> SIEM-систем. Построение CI/CD пайплайнов. Профильное образование в области информационной безопасности. Участие в <highlighttext>разработке</highlighttext>...
# Salary: None - 340000 RUR
# Vacancy ID: 90652659
# Title: Разработчик по автоматизации сетевых и облачных сервисов (Python)
# Description: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> с применением ООП и/или DDD, событийной архитектуры, технологий параллельных и распределенных вычислений. Опыт работы с...
# Vacancy ID: 89312738
# Title: Разработчик Python
# Description: Опыт работы с <highlighttext>Python</highlighttext>/Groovy от года. Глубокие знания принципов ООП. Понимание работы реляционных баз данных. Навыки написания простых SQL...
# Vacancy ID: 91001232
# Title: Python Developer (RnD AI)
# Description: Опыт коммерческой <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> в продуктовой компании от 3-х лет. Обязательно понимание того, как работать с асинхронным кодом.
# Vacancy ID: 90327943
# Title: Full-stack middle разработчик (Python, JS)
# Description: Опыт <highlighttext>разработки</highlighttext> и проектирования решений (backend + frontend) от 3 лет. Понимание архитектуры и принципов <highlighttext>разработки</highlighttext> low-code приложений.
# Vacancy ID: 91119129
# Title: Developer Python
# Description: Gitlab. - Опыт коммерческой <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> от 2 лет. - Владение хотя бы одним из фреймворков: AioHttp, Sanic, FastApi, Starlette, Django...
# Vacancy ID: 90691821
# Title: Python - разработчик
# Description: Работа в офисе. Опыт коммерческой <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> 3. Опыт работы с SQL и NoSQL базами данных. Понимание принципов ООП...
# Vacancy ID: 90688199
# Title: Backend Python Middle+ разработчик
# Description: ...в роли <highlighttext>Python</highlighttext> <highlighttext>разработчика</highlighttext> не менее 3х лет на крупных проектах. Уверенное знание языка и библиотек <highlighttext>Python</highlighttext> (3.8...
# Salary: 200000 - None RUR
# Vacancy ID: 90833586
# Title: Python разработчик
# Description: Опыт работы не менее 3х лет на крупных проектах. Уверенное знание языка <highlighttext>Python</highlighttext> (3.10-3.11) и знание...
# Vacancy ID: 90098265
# Title: Backend-разработчик Python Middle+
# Description: Опыт <highlighttext>разработки</highlighttext> серверных приложений, понимание особенностей многопроцессной и многопоточной обработки. Знание структур данных. Опыт работы с git. Опыт Linux <highlighttext>разработки</highlighttext>.
# Salary: 2000 - 2500 USD
# Vacancy ID: 86085894
# Title: Python-разработчик
# Description: Понимаешь, что такое асинхронное программирование, как оно устроено в языке <highlighttext>Python</highlighttext> и можешь работать с микросервисной архитектурой. Разбираешься в новых...
# Salary: None - 450000 RUR
# Vacancy ID: 91053778
# Title: Middle+/Senior Python developer (удаленно)
# Description: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext>, опыт с Django Framework от 3-х лет обязательно. Знание SQL, опыт работы с базами данных.
# Salary: None - 210000 RUR
# Vacancy ID: 90569966
# Title: Python Developer
# Description: Имеешь опыт работы с разными серверами баз данных. Знаешь, как настроить среду для локальной <highlighttext>разработки</highlighttext>. Понимаешь, как работать с Heroku...
# Vacancy ID: 90871839
# Title: Backend developer Python
# Description: Глубокое понимание <highlighttext>Python</highlighttext>. Знания Django, FastAPI. Проектирование сервисов и API. Владение pytest как средством для написания unit-тестов, написанием фикстур...
# Salary: 270000 - None RUR
# Vacancy ID: 90480744
# Title: Python разработчик
# Description: опыт коммерческой <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> 3.6+. - знание и опыт с aiohttp / fastapi / flask. - уверенные навыки работы с git.
# Vacancy ID: 90830492
# Title: Middle Python-разработчик
# Description: Играем на стороне клиента. Знание и опыт работы с <highlighttext>Python</highlighttext> от 3-x лет (FastAPI, Django). Понимание принципов оптимизации сервисов...
# Salary: None - 200000 RUR
# Vacancy ID: 90537884
# Title: Middle Python Backend Developer
# Description: Формат: Full time. - Коммерческий опыт <highlighttext>разработки</highlighttext> на <highlighttext>python</highlighttext> от 2-x лет. - Опыт работы с Django (либо один из известных...
# Salary: None - 200000 RUR
# Vacancy ID: 91046192
# Title: Quant Python Developer (Remote)
# Description: SQL. Кого хотим найти: <highlighttext>python</highlighttext>-<highlighttext>разработчика</highlighttext> с опытом и желанием развиваться в области алгоритмической торговли. Понимание терминологии и топологии работы...
# Vacancy ID: 88922891
# Title: Julia Developer в команду инженерного софта (Lisp, Haskell, Python)
# Description: Точно хотим видеть: Опыт работы с Julia или желание его получить. Опыт работы на функциональных языках программирования (Haskell, Scala, Elixir...
# Vacancy ID: 90110394
# Title: Middle\Senior Python разработчик (FastApi, Kafka)
# Description: Опыт коммерческой <highlighttext>разработки</highlighttext> от 3 лет. Опыт <highlighttext>разработки</highlighttext> на микросервисной архитектуре. Опыт <highlighttext>разработки</highlighttext> на наших технологиях: <highlighttext>Python</highlighttext>, FastAPI, Kafka, PostgreSQL...
# Vacancy ID: 90930614
# Title: Разработчик Python (ML)
# Description: Какие знания и навыки для нас важны: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> более 2-х лет. Знание основных концепций машинного обучения...
# Vacancy ID: 90501143
# Title: Python разработчик (Middle / Senior)
# Description: Опыт создания приложений и <highlighttext>разработки</highlighttext> API на <highlighttext>Python</highlighttext>, используя веб-фреймворки (Django либо FastAPI / Aiohttp или другой асинхронный фреймворк).
# Vacancy ID: 90993402
# Title: Middle+ Python developer (ГосТех)
# Description: Опыт коммерческой <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext>. Понимание ООП, паттернов проектирования и алгоритмов. Умение работать с асинхронным кодом. Знание SQL и умение...
# Vacancy ID: 88941764
# Title: Разработчик Python, Направление базовой инфраструктуры
# Description: Умение писать чистый и тестируемый код на <highlighttext>Python</highlighttext> (FastAPI и Django). Понимание, как работают сетевые протоколы TCP/IP.
# Vacancy ID: 90061157
# Title: Senior Python Developer (Backend)
# Description: Построение архитектуры приложений. Опыт работы с HighLoad системами. Глубокое знание <highlighttext>Python</highlighttext> 3+, Django, DRF, PostgreSQL. Понимание того как писать...
# Salary: 220000 - 250000 RUR
# Vacancy ID: 89360110
# Title: Разработчик Python, Платформа, Базовые сервисы
# Description: Опыт коммерческой <highlighttext>разработки</highlighttext> на <highlighttext>python</highlighttext> с использованием asyncio от 3х лет. Опыт написания высоконагруженных <highlighttext>python</highlighttext> приложений. Уверенное знание PostgreSQL...
# Vacancy ID: 90826740
# Title: Python разработчик (удалённо)
# Description: Опыт коммерческой <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> от 3 лет. Опыт коммерческой <highlighttext>разработки</highlighttext> с FastApi от 2 лет. Опыт работы с микросервисной...
# Salary: 200000 - 280000 RUR
# Vacancy ID: 90984139
# Title: Разработчик Python
# Description: Опыт промышленной <highlighttext>разработки</highlighttext> на <highlighttext>python</highlighttext> от четырёх лет. Есть опыт многопоточного и асинхронного программирования. Опыт написания высоконагруженных приложений (от 1000...
# Vacancy ID: 88580480
# Title: Python разработчик
# Description: Имеете опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> 3.X. Понимаете механику языка <highlighttext>Python</highlighttext> и сопутствующих инструментов (pytest, mypy, poetry, flake8).
# Vacancy ID: 90730547
# Title: Junior+/Middle Backend-разработчик (Python, fastapi, mongodb)
# Description: Целеустремленность. Открытость. Энергичность. Опыт работы над коммерческим или опен-сорс проектом. Опыт работы с mongodb. Опыт работы с rest api.
# Salary: 50000 - 120000 RUR
# Vacancy ID: 90335848
# Title: Python разработчик (django)
# Description: Опыт с Django. Опыт тестирования и поддержки кода. Опыт работы с PostgreSQL.
# Vacancy ID: 90952117
# Title: Middle Python разработчик
# Description: Вы имели опыт работы с Rust. Вы имели опыт с работой VM manager или подобными решениями.
# Salary: 100000 - 120000 RUR
# Vacancy ID: 89877206
# Title: Python-разработчик
# Description: Опыт в сфере prompt engineering. Опыт в <highlighttext>разработке</highlighttext> асинхронного и многопоточного кода. Знание экосистемы Hadoop (Hive, Spark, Oozie, HDFS, YARN...
# Vacancy ID: 90174512
# Title: Python Developer
# Description: ...командной <highlighttext>разработки</highlighttext> с применением практик DevOps. Понимание моделей архитектуры и популярных паттернов <highlighttext>разработки</highlighttext>. Опыт <highlighttext>разработки</highlighttext> cloud native приложений. Опыт <highlighttext>разработки</highlighttext>...
# Vacancy ID: 90776928
# Title: Middle Frontend разработчик (Python)
# Description: Опыт работы на <highlighttext>Python</highlighttext>. Опыт веб-<highlighttext>разработки</highlighttext> с использованием Django. Навыки работы с SQL. Умение верстать. Базовое понимание UX/UI...
# Salary: None - 200000 RUR
# Vacancy ID: 90544605
# Title: Python Backend Developer (Middle, Remote)
# Description: Умение писать юнит-тесты. Опыт промышленной <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> от 1 года. Опыт работы с очередями задач (Celery).
# Salary: None - 195000 RUR
# Vacancy ID: 90597843
# Title: Python разработчик (Биометрия)
# Description: ...<highlighttext>разработки</highlighttext> веб-приложений (JavaScript, HTML, Nginx, aiohttp/tornado). Опыт использования Jira, Confluence, Jenkins. Понимание принципов работы ОС, сетей. Опыт <highlighttext>разработки</highlighttext>...
# Vacancy ID: 90825885
# Title: Middle Python (django) разработчик
# Description: Опыт Backend <highlighttext>разработки</highlighttext> от 3-х лет. Знания фреймворка Django. Знание SQL. Опыт работы с Celery. Хорошее знание docker.
# Salary: 200000 - None RUR
# Vacancy ID: 90698994
# Title: Python разработчик
# Description: Опыт <highlighttext>разработки</highlighttext> на <highlighttext>Python</highlighttext> от 3-х лет (рассмотрим с меньшим опытом работы, для нас главное активность и интерес к...
# Salary: None - 250000 RUR
# Vacancy ID: 90293573
# Title: Python Developer
# Description: Уверенное владение <highlighttext>Python</highlighttext>. Знание операционной системы Linux. Опыт построения CI/CD пайплайнов. Понимание принципов написания хорошего кода. Умение проектировать.
